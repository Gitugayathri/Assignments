# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
data=pd.read_csv('/content/Students_Performance.csv')

# %%
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %% [markdown]
# a. Find out how many males and females participated in
# the test.

# %%
df = pd.DataFrame(data)
print(df['gender'].value_counts())
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# b. What do you think about the students' parental level of
# education?
#
# The data shows parents of all students are educated. But a few possess Masters Degree.

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# c. Who scores the most on average for math, reading and
# writing based on
# i. Gender
# ii. Test preparation course

# %%
df.groupby(['gender','test preparation course'])['math score','reading score','writing score'].mean()
# Out:
# <ipython-input-25-fff1c34360df>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['gender','test preparation course'])['math score','reading score','writing score'].mean()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948

# %% [markdown]
# d. What do you think about the scoring variation for
# math, reading and writing based on
# i. Gender
# ii. Test preparation course

# %%
df.groupby(['gender','test preparation course'])['math score','reading score','writing score'].std()
# Out:
# <ipython-input-26-52ece2734e79>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['gender','test preparation course'])['math score','reading score','writing score'].std()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 14.428233      12.695493      12.240788
#        none                      16.510686      14.636981      15.016497
# male   completed                 14.039164      13.612420      12.887910
#        none                      14.335746      13.595718      13.468284

# %% [markdown]
# e. The management needs your help to give bonus points
# to the top 25% of students based on their math score,
# so how will you help the management to achieve this.

# %%
math_25th_percentile = np.percentile(df['math score'], 25)
math_25th_percentile
top_25_percent_students = data[data['math score'] >= 57.0]
bonus_points = 5
top_25_percent_students["bonus"] = bonus_points
top_25_percent_students.to_csv("students_with_bonus.csv", index=False)
# Out:
# <ipython-input-41-c0317f3d489b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_25_percent_students["bonus"] = bonus_points

# %%
top_25_percent_students["bonus"] = bonus_points

top_25_percent_students.to_csv
# Out:
# <bound method NDFrame.to_csv of      gender race/ethnicity parental level of education         lunch  \
# 153  female        group B          associate's degree      standard
# 154  female        group B            some high school      standard
# 155  female        group C          associate's degree  free/reduced
# 156  female        group C          associate's degree      standard
# 157  female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  bonus
# ...

# %% [markdown]
# **Case Study on Testing of Hypothesis**
# 2. A company started to invest in digital marketing as a new
# way of their product promotions. For that they collected
# data and decided to carry out a study on it

# %%
import numpy as np
from scipy import stats

# %%
data=pd.read_csv('/content/Sales_add.csv')

# %%
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
Sales_before_digital_add   =  data['Sales_before_digital_add']
Sales_After_digital_add  =  data['Sales_After_digital_add']
t_val,p_val = stats.ttest_1samp(Sales_before_digital_add, Sales_After_digital_add)
aplha =0.05
if p_val<alpha:
  print("There is a significant increase in sales after implementing digital marketing.")
else:
    print("There is no significant increase in sales after implementing digital marketing.")
